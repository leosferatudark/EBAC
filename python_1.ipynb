# %% [markdown]
# <a href="https://colab.research.google.com/github/leosferatudark/EBAC/blob/main/python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # aprendendo
# ## sobre python

# %%
print ("ola leonardo")
# Out:
# ola leonardo

# %%
#test false
x = 3
13 != x
# Out:
# True

# %%
#ñ usar nomes grandes // nem muito simplificado
#soma
soma = 3 + 5
print (soma)
#soma_total    EU PREFIRO ASSIM!!!
#somaTotal
##nunca usar
#somatotaldosnumeros inteiros
# Out:
# 8

# %%
y = 6
print(x)
# Out:
# 5
