# %% [markdown]
# <a href="https://colab.research.google.com/github/leosferatudark/EBAC/blob/main/financeiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ferramenta finaceira

# %%
## Guardando seus pilares (Variáveis)
foco_atual = "Python e Trade"
empresa = "Berbel"
reserva_meta = float(input("Quanto voce tem quardado HOJE? "))

#A pergunta simples (Onde a lógica nasce)
if reserva_meta >= 10000:
  print("Meta atingida: Hora da consulta financeira!")
else:
  print(f"A lâmina ainda está sendo forjada, falta só mais um pouco. Já tem! R${reserva_meta}")
   #aqui quero entregar a evolução financeira
    # criar um contador que diz quanto falta para a META
  ## quero melhorar ainda mais, por uma lista de registro, tambem um forma de add a data....
